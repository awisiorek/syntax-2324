# %% [markdown]
# Syntax natürlicher Sprachen, WS 2023/24
#
# # 07 - Aufgabenblatt (Lösung)

# %%
import nltk
from nltk import Tree
from nltk import DependencyGraph
from spacy import displacy
from itertools import chain

# %%
def _tree_labeled(self, i):
    node = self.get_by_address(i)
    word, rel = node["word"], node["rel"]
    deps = sorted(chain.from_iterable(node["deps"].values()))
    return Tree(word + '(' + rel + ')', [self._tree_labeled(dep) for dep in deps]) if deps else word + '(' + rel + ')'

def tree_labeled(self):
    node = self.root
    word, rel = node["word"], node["rel"]
    deps = sorted(chain.from_iterable(node["deps"].values()))
    return Tree(word+'('+rel+')', [self._tree_labeled(dep) for dep in deps])

DependencyGraph._tree_labeled = _tree_labeled
DependencyGraph.tree_labeled = tree_labeled

def transform_nr_conll(sent_nr):
    sent_list = []
    for line in list(filter(None, sent_nr.split("\n"))):
        line_list = line.split(); line_list.pop(0); line_list.insert(1,"_")
        sent_list.append(" ".join([i for i in line_list[0:]]))
    return "\n".join([i for i in sent_list[0:]])

def displacy_dep_input(sent):
    deps = []
    for dep in sent.split('\n'):
        deps.append(dep.split())
    deps = [x for x in deps if x]
    ex, word_list, arc_list = [], [], []
    for index, dep in enumerate(deps):
        word_list.append({"text": dep[0], "tag": ""})
        line = index+1; head = int(dep[2]); label = dep[3]
        if head>line:
            start = index; end = head-1; direction = "left"
        else:
            start = head-1; end = index; direction = "right"
        if(label.lower() != "root"):
            arc_list.append({"start": start, "end": end, "label": label, "dir": direction})
    ex.append({"words": word_list,"arcs": arc_list})
    return ex

def show_dep_trees(sent_nr,style=1):
    sent = transform_nr_conll(sent_nr)
    dg = DependencyGraph(sent)
    if style == 0 or style == 2:
        tree_labeled = dg.tree_labeled()
        tree_labeled.pretty_print(unicodelines=True)   
    if style == 1 or style == 2:
        ex = displacy_dep_input(sent)
        html = displacy.render(ex, style="dep", manual=True, options={'distance':100})

# %% [markdown]
# ## Aufgabe 1 - Analyse komplexer Satzkonstruktion
#
# ### a) Sehen Sie sich den folgenden englischen Satz an. Können Sie sich jeweils zwei unterschiedliche Interpretationen vorstellen?
#
# - *Visiting relatives can be tiresome.*

# %%
# Lösung:
# 1. Verwandte, die zu Besuch sind
# 2. Verwandte zu besuchen

# %% [markdown]
# ### b) Erweitern Sie die gegebene Grammatik, so dass linguistisch korrekte Syntaxanalysen beider Interpretationen ausgegeben werden.
#
# ##### Verwenden Sie `VBG` für *Verb, gerund or present participle* (Penn-Treebank) und `VP-INF` für infinite Satzkonstruktionen.

# %%
sent = 'visiting relatives can be tiresome'

# %%
grammar = nltk.CFG.fromstring("""
    S -> NP VP
    NP -> VBG N
    S -> S VP
    S -> VP
    VP -> VBG NP

    VP -> AUX VP | COP ADJ
    NP -> N

    VBG -> 'visiting'
    N -> 'relatives'
    AUX -> 'can'
    COP -> 'be'
    ADJ -> 'tiresome'
""")

parser = nltk.ChartParser(grammar)
trees = list(parser.parse(sent.split()))
if trees: [tree.pretty_print(unicodelines=True) for tree in trees]
else: print(f"no parse found for: {sent}")
# Out:
#                         S
#           ┌─────────────┴───┐
#           │                 VP
#           │             ┌───┴───┐
#           NP            │       VP
#    ┌──────┴──────┐      │   ┌───┴─────┐
#   VBG            N     AUX COP       ADJ
#    │             │      │   │         │
# visiting     relatives can  be     tiresome
#
#                         S
#           ┌─────────────┴───┐
#           S                 │
#           │                 │
#           VP                VP
#    ┌──────┴──────┐      ┌───┴───┐
#    │             NP     │       VP
#    │             │      │   ┌───┴─────┐
#   VBG            N     AUX COP       ADJ
#    │             │      │   │         │
# visiting     relatives can  be     tiresome

# %% [markdown]
# ### c) Geben Sie auch die entsprechenden Dependenzstrukturanalysen an.

# %%
# 'relatives' ist Subjekt des Hautsatzes, 'visiting' ist adnominaler Dependenten von 'relatives'
sent_nr = """
1 Visiting 2 acl
2 relatives 5 nsbuj
3 can 5 aux
4 be 5 cop
5 tiresome 0 ROOT
"""
show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6ed7971610d347a09a6ddb2215554101-0" class="displacy" width="550" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Visiting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">relatives</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">tiresome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ed7971610d347a09a6ddb2215554101-0-0" stroke-width="2px" d="M70,152.0 C70,102.0 140.0,102.0 140.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ed7971610d347a09a6ddb2215554101-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ed7971610d347a09a6ddb2215554101-0-1" stroke-width="2px" d="M170,152.0 C170,2.0 450.0,2.0 450.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ed7971610d347a09a6ddb2215554101-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsbuj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,154.0 L162,142.0 178,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ed7971610d347a09a6ddb2215554101-0-2" stroke-width="2px" d="M270,152.0 C270,52.0 445.0,52.0 445.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ed7971610d347a09a6ddb2215554101-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,154.0 L262,142.0 278,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ed7971610d347a09a6ddb2215554101-0-3" stroke-width="2px" d="M370,152.0 C370,102.0 440.0,102.0 440.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ed7971610d347a09a6ddb2215554101-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,154.0 L362,142.0 378,142.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# 'visiting' ist Subjekt des Hauptsatzes (infiniter Subjektsatz), 'relatives' ist Objekt von 'visiting'
sent_nr = """
1 Visiting 5 csubj
2 relatives 1 obj
3 can 5 aux
4 be 5 cop
5 tiresome 0 ROOT
"""
show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d70a5d8f417c4de585744c65a0f9aefb-0" class="displacy" width="550" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Visiting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">relatives</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">tiresome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d70a5d8f417c4de585744c65a0f9aefb-0-0" stroke-width="2px" d="M70,152.0 C70,2.0 450.0,2.0 450.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d70a5d8f417c4de585744c65a0f9aefb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">csubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d70a5d8f417c4de585744c65a0f9aefb-0-1" stroke-width="2px" d="M70,152.0 C70,102.0 140.0,102.0 140.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d70a5d8f417c4de585744c65a0f9aefb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M140.0,154.0 L148.0,142.0 132.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d70a5d8f417c4de585744c65a0f9aefb-0-2" stroke-width="2px" d="M270,152.0 C270,52.0 445.0,52.0 445.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d70a5d8f417c4de585744c65a0f9aefb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,154.0 L262,142.0 278,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d70a5d8f417c4de585744c65a0f9aefb-0-3" stroke-width="2px" d="M370,152.0 C370,102.0 440.0,102.0 440.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d70a5d8f417c4de585744c65a0f9aefb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,154.0 L362,142.0 378,142.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Aufgabe 2 - Analyse komplexer Satzkonstruktion

# %% [markdown]
# #### Schreiben Sie eine CFG, so dass für den folgende Satz eine korrekte Syntaxanalyse ausgegeben wird. Geben Sie auch eine entsprechende Dependenzanalyse an.
#
# - *Als ich ankam, habe ich gesehen, dass sie bereits dagewesen sein mussten.*

# %%
sent = 'als ich ankam   habe ich gesehen   dass sie bereits dagewesen sein mussten'

# %% [markdown]
# #### Konstituentenanalyse:

# %%
grammar = nltk.CFG.fromstring(
    """
    S -> SBAR AUX NP VP
    SBAR -> SCONJ S
    S -> NP VP
    VP -> V | V SBAR | ADV V AUX AUX

    NP ->  N

    N -> 'ich' | 'alles' | 'sie'
    V -> 'ankam' | 'gesehen' | 'dagewesen'
    AUX -> | 'habe'| 'sein' | 'mussten'
    SCONJ -> 'als' | 'dass'
    ADV -> 'bereits'
""")

parser = nltk.ChartParser(grammar)
trees = list(parser.parse(sent.split()))
if trees: [tree.pretty_print(unicodelines=True) for tree in trees]
else: print(f"no parse found for: {sent}")
# Out:
#                                  S
#        ┌──────────────┬────┬─────┴──────┐
#        │              │    │            VP
#        │              │    │     ┌──────┴────┐
#       SBAR            │    │     │          SBAR
#   ┌────┴────┐         │    │     │      ┌────┴──────┐
#   │         S         │    │     │      │           S
#   │    ┌────┴────┐    │    │     │      │    ┌──────┴────────┐
#   │    NP        VP   │    NP    │      │    NP              VP
#   │    │         │    │    │     │      │    │      ┌────────┼──────┬──────┐
# SCONJ  N         V   AUX   N     V    SCONJ  N     ADV       V     AUX    AUX
#   │    │         │    │    │     │      │    │      │        │      │      │
#  als  ich      ankam habe ich gesehen  dass sie  bereits dagewesen sein mussten

# %% [markdown]
# #### Dependenzanalyse:

# %%
sent_nr = """
1 als 3 mark
2 ich 3 nsubj
3 ankam 6 advcl
4 habe 6 aux
5 ich 6 nsubj
6 gesehen 0 ROOT
7 dass 10 mark
8 sie 10 nsubj
9 bereits 10 advmod
10 dagewesen 6 ccomp
11 sein 10 aux
12 mussten 10 aux
"""

show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b442612089104e9897f1a95195db3e8c-0" class="displacy" width="1250" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">als</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">ich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">ankam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">habe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">ich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">gesehen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">dass</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">sie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">bereits</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">dagewesen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">sein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">mussten</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-0" stroke-width="2px" d="M70,202.0 C70,102.0 240.0,102.0 240.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-1" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-2" stroke-width="2px" d="M270,202.0 C270,52.0 545.0,52.0 545.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-3" stroke-width="2px" d="M370,202.0 C370,102.0 540.0,102.0 540.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-4" stroke-width="2px" d="M470,202.0 C470,152.0 535.0,152.0 535.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,204.0 L462,192.0 478,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-5" stroke-width="2px" d="M670,202.0 C670,52.0 945.0,52.0 945.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,204.0 L662,192.0 678,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-6" stroke-width="2px" d="M770,202.0 C770,102.0 940.0,102.0 940.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,204.0 L762,192.0 778,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-7" stroke-width="2px" d="M870,202.0 C870,152.0 935.0,152.0 935.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b442612089104e9897f1a95195db3e8c-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,204.0 L862,192.0 878,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b442612089104e9897f1a95195db3e8c-0-8" stroke-width="2
